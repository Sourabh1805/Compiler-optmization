# %%
code_file= 'sum.c'

# %%
compatible_flags = [
    '-fauto-inc-dec', '-fbranch-count-reg', '-fcombine-stack-adjustments', '-fcompare-elim',
    '-fcprop-registers', '-fdce', '-fdefer-pop', '-fdelayed-branch', '-fdse', '-fforward-propagate',
    '-fguess-branch-probability', '-fif-conversion', '-fif-conversion2', '-finline-functions-called-once',
    '-fipa-modref', '-fipa-profile', '-fipa-pure-const', '-fipa-reference', '-fipa-reference-addressable',
    '-fmerge-constants', '-fmove-loop-invariants', '-fomit-frame-pointer', '-freorder-blocks', '-fshrink-wrap',
    '-fshrink-wrap-separate', '-fsplit-wide-types', '-fssa-backprop', '-fssa-phiopt', '-ftree-bit-ccp',
    '-ftree-ccp', '-ftree-ch', '-ftree-coalesce-vars', '-ftree-copy-prop', '-ftree-dce', '-ftree-dominator-opts',
    '-ftree-dse', '-ftree-forwprop', '-ftree-fre', '-ftree-phiprop', '-ftree-pta', '-ftree-scev-cprop', '-ftree-sink',
    '-ftree-slsr', '-ftree-sra', '-ftree-ter', '-funit-at-a-time', '-falign-functions', '-falign-jumps', '-falign-labels',
    '-falign-loops', '-fcaller-saves', '-fcode-hoisting', '-fcrossjumping', '-fcse-follow-jumps', '-fcse-skip-blocks',
    '-fdelete-null-pointer-checks', '-fdevirtualize', '-fdevirtualize-speculatively', '-fexpensive-optimizations',
    '-ffinite-loops', '-fgcse', '-fgcse-lm', '-fhoist-adjacent-loads', '-finline-functions', '-finline-small-functions',
    '-findirect-inlining', '-fipa-bit-cp', '-fipa-cp', '-fipa-icf', '-fipa-ra', '-fipa-sra', '-fipa-vrp',
    '-fisolate-erroneous-paths-dereference', '-flra-remat', '-foptimize-sibling-calls', '-foptimize-strlen',
    '-fpartial-inlining', '-fpeephole2', '-freorder-blocks-algorithm=stc', '-freorder-blocks-and-partition',
    '-freorder-functions', '-frerun-cse-after-loop', '-fschedule-insns', '-fschedule-insns2', '-fsched-interblock',
    '-fsched-spec', '-fstore-merging', '-fstrict-aliasing', '-fthread-jumps', '-ftree-builtin-call-dce',
    '-ftree-loop-vectorize', '-ftree-pre', '-ftree-slp-vectorize', '-ftree-switch-conversion', '-ftree-tail-merge',
    '-ftree-vrp', '-fvect-cost-model=very-cheap', '-fgcse-after-reload', '-fipa-cp-clone', '-floop-interchange',
    '-floop-unroll-and-jam', '-fpeel-loops', '-fpredictive-commoning', '-fsplit-loops', '-fsplit-paths',
    '-ftree-loop-distribution', '-ftree-partial-pre', '-funswitch-loops', '-fvect-cost-model=dynamic',
    '-fversion-loops-for-strides'
]

# %%
#!pip uninstall torch
#!pip install torch
# Out:
# Found existing installation: torch 2.3.1+cu121
# Uninstalling torch-2.3.1+cu121:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.10/dist-packages/functorch/*
#     /usr/local/lib/python3.10/dist-packages/torch-2.3.1+cu121.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/torch/*
#     /usr/local/lib/python3.10/dist-packages/torchgen/*
# Proceed (Y/n)? Y
#   Successfully uninstalled torch-2.3.1+cu121
# Collecting torch
#   Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Collecting triton==3.0.0 (from torch)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.20)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Downloading torch-2.4.0-cp310-cp310-manylinux1_x86_64.whl (797.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 6.0 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cudnn-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.3.1
#     Uninstalling triton-2.3.1:
#       Successfully uninstalled triton-2.3.1
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.2.26
#     Uninstalling nvidia-cudnn-cu12-8.9.2.26:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.2.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# torchvision 0.18.1+cu121 requires torch==2.3.1, but you have torch 2.4.0 which is incompatible.
# Successfully installed nvidia-cudnn-cu12-9.1.0.70 torch-2.4.0 triton-3.0.0

# %%
import subprocess
class CompilerEnv:
    def __init__(self, code_path):
        self.code_path = code_path
        self.flags = compatible_flags
        self.state_space = len(self.flags)
        self.action_space = len(self.flags)
        self.current_state = tuple([0] * self.state_space)

    def reset(self):
        self.current_state = tuple([0] * self.state_space)
        return self.current_state

    def compile_and_measure(self, flags):
        flags_str = ' '.join([self.flags[i] for i, flag in enumerate(flags) if flag])
        compile_command = f"gcc {self.code_path} {flags_str} -o output"
        run_command = "./output"

        try:
            compile_result = subprocess.run(compile_command, shell=True, capture_output=True, text=True, timeout=10)
            if compile_result.returncode != 0:
                print("Compilation failed:", compile_result.stderr)
                return float('inf')

            subprocess.run(f"chmod +x output", shell=True)

            run_result = subprocess.run(run_command, shell=True, capture_output=True, text=True, timeout=10)
            if run_result.returncode != 0:
                print("Execution failed:", run_result.stderr)
                return float('inf')

            output_lines = run_result.stdout.strip().split('\n')
            execution_time = float(output_lines[-1])
            return execution_time

        except subprocess.TimeoutExpired:
            print("Execution timed out")
            return float('inf')

    def step(self, action):
        current_flags = list(self.current_state)
        current_flags[action] = 1 - current_flags[action]
        self.current_state = tuple(current_flags)

        execution_time = self.compile_and_measure(self.current_state)
        reward = -execution_time

        return self.current_state, reward, False

    def render(self):
        print(f"State: {self.current_state}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt

# Define the neural network used for DQN
class DQNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(DQNetwork, self).__init__()
        # A simple feedforward neural network with two hidden layers
        self.fc1 = nn.Linear(state_space, 24)
        self.fc2 = nn.Linear(24, 24)
        self.fc3 = nn.Linear(24, action_space)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# DQN agent class
class DQNAgent:
    def __init__(self, state_space, action_space, learning_rate=0.001, discount_factor=0.99, exploration_rate=1.0,
                 exploration_decay=0.995, memory_size=1000, batch_size=32, target_update_frequency=10):
        self.state_space = state_space
        self.action_space = action_space
        self.lr = learning_rate
        self.gamma = discount_factor
        self.epsilon = exploration_rate
        self.epsilon_decay = exploration_decay
        self.memory = deque(maxlen=memory_size)
        self.batch_size = batch_size

        # Initialize the main and target networks
        self.model = DQNetwork(state_space, action_space)
        self.target_model = DQNetwork(state_space, action_space)
        self.update_target_network()

        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()

        self.target_update_frequency = target_update_frequency
        self.steps_done = 0

    def choose_action(self, state):
        # Implement epsilon-greedy action selection
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.choice(self.action_space)
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state_tensor)
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample a batch from the replay buffer
        batch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in batch:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)

            # Compute the predicted Q-values for the current state
            q_values = self.model(state_tensor)
            q_value = q_values[0, action]

            # Compute the target Q-value
            with torch.no_grad():
                next_q_values = self.target_model(next_state_tensor)
                next_q_value = torch.max(next_q_values)

            # Set the target Q-value for the current action
            target = reward + (1 - done) * self.gamma * next_q_value

            # Compute the loss
            loss = self.loss_fn(q_value, target)

            # Perform a gradient descent step
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        # Decay epsilon
        self.epsilon *= self.epsilon_decay

        # Update the target network periodically
        if self.steps_done % self.target_update_frequency == 0:
            self.update_target_network()

        self.steps_done += 1

    def update_target_network(self):
        self.target_model.load_state_dict(self.model.state_dict())

def train_dqn(agent, env, episodes=1000):
    rewards = []

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        episode_rewards = []

        for step in range(100):
            action = agent.choose_action(state)
            next_state, reward, done = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            episode_rewards.append(reward)

            if done:
                break

        agent.replay()
        rewards.append(total_reward)
        min_reward = min(episode_rewards)
        max_reward = max(episode_rewards)
        avg_reward = np.mean(episode_rewards)

        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}, Min Reward: {min_reward:.10f}, Max Reward: {max_reward:.10f}, Average Reward: {avg_reward}")

    plt.figure(figsize=(10, 6))
    plt.plot(range(episodes), rewards, marker='o', linestyle='-')
    plt.xlabel('Episodes')
    plt.ylabel('Total Rewards')
    plt.title('Episodes vs. Total Rewards per Episode (DQN)')
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.10f}'))
    plt.grid(True)
    plt.show()

# Example of running a DQN experiment
new_code_path = 'sum.c'  # Specify the path to your C program
env = CompilerEnv(new_code_path)
dqn_agent = DQNAgent(env.state_space, env.action_space)

train_dqn(dqn_agent, env)
# Out:
# Episode 1/1000, Total Reward: -3.155949999999999, Min Reward: -0.0343000000, Max Reward: -0.0263870000, Average Reward: -0.0315595
# Episode 2/1000, Total Reward: -3.265641, Min Reward: -0.0346020000, Max Reward: -0.0266000000, Average Reward: -0.03265641
# Episode 3/1000, Total Reward: -3.227368000000001, Min Reward: -0.0348760000, Max Reward: -0.0263480000, Average Reward: -0.03227368
# Episode 4/1000, Total Reward: -3.155821999999999, Min Reward: -0.0348020000, Max Reward: -0.0262520000, Average Reward: -0.03155822
# Episode 5/1000, Total Reward: -3.1716590000000005, Min Reward: -0.0346910000, Max Reward: -0.0265620000, Average Reward: -0.031716589999999996
# Episode 6/1000, Total Reward: -3.332725, Min Reward: -0.0348070000, Max Reward: -0.0273940000, Average Reward: -0.03332725
# Episode 7/1000, Total Reward: -3.148561000000001, Min Reward: -0.0345790000, Max Reward: -0.0263000000, Average Reward: -0.03148561
# Episode 8/1000, Total Reward: -3.1604509999999992, Min Reward: -0.0349140000, Max Reward: -0.0263210000, Average Reward: -0.03160451
# Episode 9/1000, Total Reward: -3.2245790000000016, Min Reward: -0.0344150000, Max Reward: -0.0264580000, Average Reward: -0.032245789999999996
# Episode 10/1000, Total Reward: -3.2665849999999996, Min Reward: -0.0346030000, Max Reward: -0.0266770000, Average Reward: -0.032665849999999996
# Episode 11/1000, Total Reward: -3.1627679999999994, Min Reward: -0.0346790000, Max Reward: -0.0263320000, Average Reward: -0.031627680000000005
# Episode 12/1000, Total Reward: -3.1559579999999983, Min Reward: -0.0347460000, Max Reward: -0.0264960000, Average Reward: -0.031559580000000004
# Episode 13/1000, Total Reward: -3.314779, Min Reward: -0.0347980000, Max Reward: -0.0280320000, Average Reward: -0.033147789999999996
# Episode 14/1000, Total Reward: -3.160676000000001, Min Reward: -0.0346300000, Max Reward: -0.0264080000, Average Reward: -0.031606760000000005
# Episode 15/1000, Total Reward: -3.1594209999999996, Min Reward: -0.0347240000, Max Reward: -0.0264940000, Average Reward: -0.03159421
# Episode 16/1000, Total Reward: -3.2254390000000006, Min Reward: -0.0344140000, Max Reward: -0.0262750000, Average Reward: -0.03225439
# Episode 17/1000, Total Reward: -3.2775900000000004, Min Reward: -0.0350010000, Max Reward: -0.0270970000, Average Reward: -0.0327759
# Episode 18/1000, Total Reward: -3.1685070000000013, Min Reward: -0.0346790000, Max Reward: -0.0263890000, Average Reward: -0.03168507
# Episode 19/1000, Total Reward: -3.1763350000000004, Min Reward: -0.0347130000, Max Reward: -0.0265010000, Average Reward: -0.031763349999999996
# Episode 20/1000, Total Reward: -3.3147110000000004, Min Reward: -0.0345310000, Max Reward: -0.0270890000, Average Reward: -0.03314711000000001
# Episode 21/1000, Total Reward: -3.1759779999999997, Min Reward: -0.0346400000, Max Reward: -0.0263640000, Average Reward: -0.03175978
# Episode 22/1000, Total Reward: -3.175753000000001, Min Reward: -0.0347830000, Max Reward: -0.0265460000, Average Reward: -0.031757530000000006
# Episode 23/1000, Total Reward: -3.168500000000002, Min Reward: -0.0346800000, Max Reward: -0.0263290000, Average Reward: -0.031685000000000005
# Episode 24/1000, Total Reward: -3.323810999999999, Min Reward: -0.0345240000, Max Reward: -0.0278720000, Average Reward: -0.033238109999999994
# Episode 25/1000, Total Reward: -3.174740999999999, Min Reward: -0.0347240000, Max Reward: -0.0264170000, Average Reward: -0.03174741
# Episode 26/1000, Total Reward: -3.1565450000000004, Min Reward: -0.0347350000, Max Reward: -0.0264620000, Average Reward: -0.03156545
# Episode 27/1000, Total Reward: -3.266522999999998, Min Reward: -0.0347570000, Max Reward: -0.0265160000, Average Reward: -0.032665229999999996
# Episode 28/1000, Total Reward: -3.1909490000000003, Min Reward: -0.0535370000, Max Reward: -0.0263680000, Average Reward: -0.03190949
# Episode 29/1000, Total Reward: -3.0999789999999994, Min Reward: -0.0364940000, Max Reward: -0.0263550000, Average Reward: -0.03099979
# Episode 30/1000, Total Reward: -3.1651430000000014, Min Reward: -0.0347040000, Max Reward: -0.0262230000, Average Reward: -0.03165143000000001
# Episode 31/1000, Total Reward: -3.298246, Min Reward: -0.0348180000, Max Reward: -0.0264560000, Average Reward: -0.03298246
# Episode 32/1000, Total Reward: -3.1923019999999993, Min Reward: -0.0350260000, Max Reward: -0.0265160000, Average Reward: -0.03192302
# Episode 33/1000, Total Reward: -3.1575559999999996, Min Reward: -0.0345890000, Max Reward: -0.0264350000, Average Reward: -0.03157556
# Episode 34/1000, Total Reward: -3.165816, Min Reward: -0.0344480000, Max Reward: -0.0264570000, Average Reward: -0.03165816
# Episode 35/1000, Total Reward: -3.3360659999999998, Min Reward: -0.0347310000, Max Reward: -0.0279040000, Average Reward: -0.03336066
# Episode 36/1000, Total Reward: -3.1578079999999993, Min Reward: -0.0347010000, Max Reward: -0.0264360000, Average Reward: -0.031578079999999994
# Episode 37/1000, Total Reward: -3.1494149999999994, Min Reward: -0.0348590000, Max Reward: -0.0263360000, Average Reward: -0.031494150000000005
# Episode 38/1000, Total Reward: -3.2740049999999985, Min Reward: -0.0346950000, Max Reward: -0.0265870000, Average Reward: -0.03274005
# Episode 39/1000, Total Reward: -3.2146810000000006, Min Reward: -0.0350450000, Max Reward: -0.0263570000, Average Reward: -0.03214681
# Episode 40/1000, Total Reward: -3.1435389999999996, Min Reward: -0.0343510000, Max Reward: -0.0263350000, Average Reward: -0.03143539
# Episode 41/1000, Total Reward: -3.163452000000001, Min Reward: -0.0346750000, Max Reward: -0.0262650000, Average Reward: -0.03163452
# Episode 42/1000, Total Reward: -3.3289320000000004, Min Reward: -0.0347170000, Max Reward: -0.0279140000, Average Reward: -0.03328932
# Episode 43/1000, Total Reward: -3.1662420000000004, Min Reward: -0.0342820000, Max Reward: -0.0263210000, Average Reward: -0.03166242
# Episode 44/1000, Total Reward: -3.1523660000000002, Min Reward: -0.0347130000, Max Reward: -0.0264180000, Average Reward: -0.031523659999999995
# Episode 45/1000, Total Reward: -3.260459, Min Reward: -0.0348920000, Max Reward: -0.0265780000, Average Reward: -0.03260459
# Episode 46/1000, Total Reward: -3.2288969999999986, Min Reward: -0.0343900000, Max Reward: -0.0264800000, Average Reward: -0.03228897
# Episode 47/1000, Total Reward: -3.1628529999999992, Min Reward: -0.0344750000, Max Reward: -0.0263740000, Average Reward: -0.031628529999999995
# Episode 48/1000, Total Reward: -3.168402000000001, Min Reward: -0.0348270000, Max Reward: -0.0263840000, Average Reward: -0.03168402
# Episode 49/1000, Total Reward: -3.3345800000000003, Min Reward: -0.0350640000, Max Reward: -0.0271400000, Average Reward: -0.0333458
# Episode 50/1000, Total Reward: -3.1563170000000005, Min Reward: -0.0347640000, Max Reward: -0.0263070000, Average Reward: -0.03156317
# Episode 51/1000, Total Reward: -3.174859000000001, Min Reward: -0.0350950000, Max Reward: -0.0264890000, Average Reward: -0.03174859
# Episode 52/1000, Total Reward: -3.211762999999999, Min Reward: -0.0343800000, Max Reward: -0.0263220000, Average Reward: -0.032117629999999994
# Episode 53/1000, Total Reward: -3.273055, Min Reward: -0.0347670000, Max Reward: -0.0264980000, Average Reward: -0.03273055
# Episode 54/1000, Total Reward: -3.1778930000000014, Min Reward: -0.0349280000, Max Reward: -0.0263490000, Average Reward: -0.031778930000000004
# Episode 55/1000, Total Reward: -3.1605380000000003, Min Reward: -0.0347600000, Max Reward: -0.0264050000, Average Reward: -0.03160538
# Episode 56/1000, Total Reward: -3.3392629999999994, Min Reward: -0.0345640000, Max Reward: -0.0283100000, Average Reward: -0.03339263
# Episode 57/1000, Total Reward: -3.152630999999999, Min Reward: -0.0347720000, Max Reward: -0.0263640000, Average Reward: -0.03152631
# Episode 58/1000, Total Reward: -3.1587399999999994, Min Reward: -0.0350150000, Max Reward: -0.0264990000, Average Reward: -0.031587399999999995
# Episode 59/1000, Total Reward: -3.202992000000001, Min Reward: -0.0345880000, Max Reward: -0.0264520000, Average Reward: -0.03202992
# Episode 60/1000, Total Reward: -3.298675999999998, Min Reward: -0.0348790000, Max Reward: -0.0271050000, Average Reward: -0.03298676
# Episode 61/1000, Total Reward: -3.1631669999999996, Min Reward: -0.0345820000, Max Reward: -0.0264130000, Average Reward: -0.031631669999999994
# Episode 62/1000, Total Reward: -3.1485499999999975, Min Reward: -0.0346040000, Max Reward: -0.0263440000, Average Reward: -0.0314855
# Episode 63/1000, Total Reward: -3.3121740000000006, Min Reward: -0.0346930000, Max Reward: -0.0271530000, Average Reward: -0.033121740000000004
# Episode 64/1000, Total Reward: -3.190673, Min Reward: -0.0346490000, Max Reward: -0.0264860000, Average Reward: -0.03190673
# Episode 65/1000, Total Reward: -3.1441399999999984, Min Reward: -0.0344340000, Max Reward: -0.0264260000, Average Reward: -0.0314414
# Episode 66/1000, Total Reward: -3.152102000000001, Min Reward: -0.0344340000, Max Reward: -0.0264940000, Average Reward: -0.03152102
# Episode 67/1000, Total Reward: -3.3377400000000006, Min Reward: -0.0355170000, Max Reward: -0.0271760000, Average Reward: -0.033377399999999995
# Episode 68/1000, Total Reward: -3.1636630000000006, Min Reward: -0.0349140000, Max Reward: -0.0265080000, Average Reward: -0.03163663
# Episode 69/1000, Total Reward: -3.169066000000001, Min Reward: -0.0345060000, Max Reward: -0.0263940000, Average Reward: -0.031690659999999995
# Episode 70/1000, Total Reward: -3.2823209999999996, Min Reward: -0.0349220000, Max Reward: -0.0265560000, Average Reward: -0.032823210000000005
# Episode 71/1000, Total Reward: -3.2284059999999983, Min Reward: -0.0346720000, Max Reward: -0.0264100000, Average Reward: -0.03228406
# Episode 72/1000, Total Reward: -3.155735999999999, Min Reward: -0.0347200000, Max Reward: -0.0264270000, Average Reward: -0.03155735999999999
# Episode 73/1000, Total Reward: -3.1762369999999995, Min Reward: -0.0343920000, Max Reward: -0.0264300000, Average Reward: -0.03176237
# Episode 74/1000, Total Reward: -3.3362779999999983, Min Reward: -0.0352000000, Max Reward: -0.0283390000, Average Reward: -0.03336278
# Episode 75/1000, Total Reward: -3.1550489999999987, Min Reward: -0.0354270000, Max Reward: -0.0263700000, Average Reward: -0.031550489999999994
# Episode 76/1000, Total Reward: -3.1788810000000014, Min Reward: -0.0345370000, Max Reward: -0.0264380000, Average Reward: -0.03178881
# Episode 77/1000, Total Reward: -3.2564059999999992, Min Reward: -0.0348090000, Max Reward: -0.0265250000, Average Reward: -0.03256405999999999
# Episode 78/1000, Total Reward: -3.305646, Min Reward: -0.0349950000, Max Reward: -0.0270170000, Average Reward: -0.033056459999999996
# Episode 79/1000, Total Reward: -3.3147219999999997, Min Reward: -0.0463550000, Max Reward: -0.0266080000, Average Reward: -0.033147220000000005
# Episode 80/1000, Total Reward: -3.1951750000000003, Min Reward: -0.0350260000, Max Reward: -0.0265690000, Average Reward: -0.03195175
# Episode 81/1000, Total Reward: -3.2539809999999987, Min Reward: -0.0346580000, Max Reward: -0.0265100000, Average Reward: -0.032539809999999995
# Episode 82/1000, Total Reward: -3.261620000000001, Min Reward: -0.0349100000, Max Reward: -0.0264090000, Average Reward: -0.032616200000000005
# Episode 83/1000, Total Reward: -3.185267, Min Reward: -0.0351370000, Max Reward: -0.0264580000, Average Reward: -0.03185267
# Episode 84/1000, Total Reward: -3.169026999999998, Min Reward: -0.0349570000, Max Reward: -0.0265450000, Average Reward: -0.03169027
# Episode 85/1000, Total Reward: -3.3421090000000007, Min Reward: -0.0346530000, Max Reward: -0.0287950000, Average Reward: -0.03342109000000001
# Episode 86/1000, Total Reward: -3.1812319999999996, Min Reward: -0.0348450000, Max Reward: -0.0264440000, Average Reward: -0.03181232
# Episode 87/1000, Total Reward: -3.1675189999999995, Min Reward: -0.0345850000, Max Reward: -0.0265550000, Average Reward: -0.031675190000000006
# Episode 88/1000, Total Reward: -3.1828250000000007, Min Reward: -0.0347650000, Max Reward: -0.0265860000, Average Reward: -0.03182825
# Episode 89/1000, Total Reward: -3.333136999999998, Min Reward: -0.0344510000, Max Reward: -0.0274720000, Average Reward: -0.03333137
# Episode 90/1000, Total Reward: -3.1745249999999996, Min Reward: -0.0344440000, Max Reward: -0.0266730000, Average Reward: -0.03174525
# Episode 91/1000, Total Reward: -3.154288999999999, Min Reward: -0.0345550000, Max Reward: -0.0263120000, Average Reward: -0.031542890000000004
# Episode 92/1000, Total Reward: -3.2675899999999998, Min Reward: -0.0347180000, Max Reward: -0.0264280000, Average Reward: -0.0326759
# Episode 93/1000, Total Reward: -3.2448899999999994, Min Reward: -0.0346530000, Max Reward: -0.0264270000, Average Reward: -0.0324489
# Episode 94/1000, Total Reward: -3.162457000000002, Min Reward: -0.0568770000, Max Reward: -0.0266600000, Average Reward: -0.031624570000000005
# Episode 95/1000, Total Reward: -3.1738939999999993, Min Reward: -0.0344940000, Max Reward: -0.0262810000, Average Reward: -0.03173894
# Episode 96/1000, Total Reward: -3.2486180000000004, Min Reward: -0.0346360000, Max Reward: -0.0263730000, Average Reward: -0.03248618
# Episode 97/1000, Total Reward: -3.2734729999999996, Min Reward: -0.0349840000, Max Reward: -0.0267860000, Average Reward: -0.032734730000000004
# Episode 98/1000, Total Reward: -3.2058979999999995, Min Reward: -0.0348720000, Max Reward: -0.0264560000, Average Reward: -0.03205898
# Episode 99/1000, Total Reward: -3.2029100000000006, Min Reward: -0.0350910000, Max Reward: -0.0266290000, Average Reward: -0.032029100000000005
# Episode 100/1000, Total Reward: -3.3115459999999985, Min Reward: -0.0347050000, Max Reward: -0.0265460000, Average Reward: -0.033115460000000006
# Episode 101/1000, Total Reward: -3.2076170000000017, Min Reward: -0.0347560000, Max Reward: -0.0264400000, Average Reward: -0.03207617
# Episode 102/1000, Total Reward: -3.180902, Min Reward: -0.0345600000, Max Reward: -0.0263800000, Average Reward: -0.03180902
# Episode 103/1000, Total Reward: -3.168975000000001, Min Reward: -0.0346750000, Max Reward: -0.0263610000, Average Reward: -0.03168975
# Episode 104/1000, Total Reward: -3.330536999999999, Min Reward: -0.0353820000, Max Reward: -0.0280400000, Average Reward: -0.033305369999999994
# Episode 105/1000, Total Reward: -3.1732959999999992, Min Reward: -0.0348470000, Max Reward: -0.0263170000, Average Reward: -0.031732960000000004
# Episode 106/1000, Total Reward: -3.163670999999999, Min Reward: -0.0350020000, Max Reward: -0.0265490000, Average Reward: -0.031636710000000005
# Episode 107/1000, Total Reward: -3.233104000000001, Min Reward: -0.0348450000, Max Reward: -0.0264270000, Average Reward: -0.03233104
# Episode 108/1000, Total Reward: -3.2773980000000007, Min Reward: -0.0350250000, Max Reward: -0.0268100000, Average Reward: -0.03277398
# Episode 109/1000, Total Reward: -3.1741540000000006, Min Reward: -0.0347450000, Max Reward: -0.0264460000, Average Reward: -0.03174154
# Episode 110/1000, Total Reward: -3.1761439999999994, Min Reward: -0.0343080000, Max Reward: -0.0264550000, Average Reward: -0.03176144
# Episode 111/1000, Total Reward: -3.302384000000001, Min Reward: -0.0349320000, Max Reward: -0.0266280000, Average Reward: -0.03302384
# Episode 112/1000, Total Reward: -3.1979300000000013, Min Reward: -0.0347150000, Max Reward: -0.0263760000, Average Reward: -0.0319793
# Episode 113/1000, Total Reward: -3.171172, Min Reward: -0.0352950000, Max Reward: -0.0264150000, Average Reward: -0.03171172
# Episode 114/1000, Total Reward: -3.1638480000000015, Min Reward: -0.0348910000, Max Reward: -0.0265330000, Average Reward: -0.031638480000000004
# Episode 115/1000, Total Reward: -3.309303999999999, Min Reward: -0.0351150000, Max Reward: -0.0274650000, Average Reward: -0.03309304
# Episode 116/1000, Total Reward: -3.1490530000000008, Min Reward: -0.0343850000, Max Reward: -0.0264190000, Average Reward: -0.03149053
# Episode 117/1000, Total Reward: -3.143561000000001, Min Reward: -0.0343740000, Max Reward: -0.0263010000, Average Reward: -0.03143561
# Episode 118/1000, Total Reward: -3.2818789999999987, Min Reward: -0.0347410000, Max Reward: -0.0264590000, Average Reward: -0.032818789999999994
# Episode 119/1000, Total Reward: -3.2323659999999994, Min Reward: -0.0344880000, Max Reward: -0.0264370000, Average Reward: -0.03232366
# Episode 120/1000, Total Reward: -3.1547490000000025, Min Reward: -0.0346030000, Max Reward: -0.0264180000, Average Reward: -0.03154749
# Episode 121/1000, Total Reward: -3.1529259999999995, Min Reward: -0.0347760000, Max Reward: -0.0263780000, Average Reward: -0.031529259999999996
# Episode 122/1000, Total Reward: -3.3189779999999995, Min Reward: -0.0344540000, Max Reward: -0.0272810000, Average Reward: -0.03318978
# Episode 123/1000, Total Reward: -3.1734260000000014, Min Reward: -0.0344890000, Max Reward: -0.0264340000, Average Reward: -0.03173426
# Episode 124/1000, Total Reward: -3.144561, Min Reward: -0.0346290000, Max Reward: -0.0263490000, Average Reward: -0.03144561
# Episode 125/1000, Total Reward: -3.2364990000000002, Min Reward: -0.0346680000, Max Reward: -0.0262750000, Average Reward: -0.032364989999999996
# Episode 126/1000, Total Reward: -3.2719019999999994, Min Reward: -0.0346620000, Max Reward: -0.0265930000, Average Reward: -0.03271902
# Episode 127/1000, Total Reward: -3.1841629999999985, Min Reward: -0.0354140000, Max Reward: -0.0263940000, Average Reward: -0.031841629999999996
# Episode 128/1000, Total Reward: -3.2025680000000016, Min Reward: -0.0365760000, Max Reward: -0.0265410000, Average Reward: -0.03202568
# Episode 129/1000, Total Reward: -3.3254399999999986, Min Reward: -0.0347800000, Max Reward: -0.0270470000, Average Reward: -0.033254399999999996
# Episode 130/1000, Total Reward: -3.198089000000001, Min Reward: -0.0347570000, Max Reward: -0.0264660000, Average Reward: -0.031980890000000005
# Episode 131/1000, Total Reward: -3.161694999999998, Min Reward: -0.0346690000, Max Reward: -0.0264490000, Average Reward: -0.031616950000000005
# Episode 132/1000, Total Reward: -3.177318, Min Reward: -0.0348130000, Max Reward: -0.0265160000, Average Reward: -0.03177318
# Episode 133/1000, Total Reward: -3.3620939999999995, Min Reward: -0.0350750000, Max Reward: -0.0280470000, Average Reward: -0.03362094
# Episode 134/1000, Total Reward: -3.164201, Min Reward: -0.0344970000, Max Reward: -0.0264010000, Average Reward: -0.031642010000000005
# Episode 135/1000, Total Reward: -3.176385, Min Reward: -0.0350730000, Max Reward: -0.0263720000, Average Reward: -0.03176385
# Episode 136/1000, Total Reward: -3.236113, Min Reward: -0.0345870000, Max Reward: -0.0264440000, Average Reward: -0.03236113
# Episode 137/1000, Total Reward: -3.2534320000000005, Min Reward: -0.0345560000, Max Reward: -0.0264250000, Average Reward: -0.03253432
# Episode 138/1000, Total Reward: -3.188548, Min Reward: -0.0351370000, Max Reward: -0.0264680000, Average Reward: -0.03188548
# Episode 139/1000, Total Reward: -3.1817929999999994, Min Reward: -0.0348160000, Max Reward: -0.0264660000, Average Reward: -0.03181793
# Episode 140/1000, Total Reward: -3.303921999999999, Min Reward: -0.0350080000, Max Reward: -0.0267710000, Average Reward: -0.03303922000000001
# Episode 141/1000, Total Reward: -3.2031839999999976, Min Reward: -0.0355360000, Max Reward: -0.0264140000, Average Reward: -0.03203184
# Episode 142/1000, Total Reward: -3.1661319999999984, Min Reward: -0.0350820000, Max Reward: -0.0264230000, Average Reward: -0.03166132
# Episode 143/1000, Total Reward: -3.1816109999999997, Min Reward: -0.0347210000, Max Reward: -0.0264500000, Average Reward: -0.03181611000000001
# Episode 144/1000, Total Reward: -3.3185850000000015, Min Reward: -0.0348330000, Max Reward: -0.0295660000, Average Reward: -0.03318585
# Episode 145/1000, Total Reward: -3.162297000000001, Min Reward: -0.0345680000, Max Reward: -0.0264880000, Average Reward: -0.03162297
# Episode 146/1000, Total Reward: -3.157419000000001, Min Reward: -0.0347800000, Max Reward: -0.0264910000, Average Reward: -0.03157419
# Episode 147/1000, Total Reward: -3.2369039999999982, Min Reward: -0.0347300000, Max Reward: -0.0263990000, Average Reward: -0.03236904
# Episode 148/1000, Total Reward: -3.2800780000000005, Min Reward: -0.0349840000, Max Reward: -0.0268140000, Average Reward: -0.03280078
# Episode 149/1000, Total Reward: -3.1603959999999978, Min Reward: -0.0348940000, Max Reward: -0.0264320000, Average Reward: -0.03160396
# Episode 150/1000, Total Reward: -3.1769720000000006, Min Reward: -0.0344770000, Max Reward: -0.0265740000, Average Reward: -0.031769719999999994
# Episode 151/1000, Total Reward: -3.323187000000001, Min Reward: -0.0348440000, Max Reward: -0.0266350000, Average Reward: -0.03323187
# Episode 152/1000, Total Reward: -3.2038010000000017, Min Reward: -0.0344290000, Max Reward: -0.0265010000, Average Reward: -0.032038010000000006
# Episode 153/1000, Total Reward: -3.1525050000000014, Min Reward: -0.0349560000, Max Reward: -0.0264220000, Average Reward: -0.03152505
# Episode 154/1000, Total Reward: -3.161537999999997, Min Reward: -0.0346380000, Max Reward: -0.0265030000, Average Reward: -0.03161538
# Episode 155/1000, Total Reward: -3.3158240000000005, Min Reward: -0.0344790000, Max Reward: -0.0277690000, Average Reward: -0.03315824
# Episode 156/1000, Total Reward: -3.167039999999999, Min Reward: -0.0347610000, Max Reward: -0.0264410000, Average Reward: -0.0316704
# Episode 157/1000, Total Reward: -3.1585730000000005, Min Reward: -0.0344930000, Max Reward: -0.0263700000, Average Reward: -0.03158573
# Episode 158/1000, Total Reward: -3.268303, Min Reward: -0.0346940000, Max Reward: -0.0265680000, Average Reward: -0.032683029999999995
# Episode 159/1000, Total Reward: -3.2304880000000007, Min Reward: -0.0346410000, Max Reward: -0.0263200000, Average Reward: -0.03230488
# Episode 160/1000, Total Reward: -3.186276000000001, Min Reward: -0.0347760000, Max Reward: -0.0266120000, Average Reward: -0.03186276
# Episode 161/1000, Total Reward: -3.168467, Min Reward: -0.0348300000, Max Reward: -0.0264130000, Average Reward: -0.03168467
# Episode 162/1000, Total Reward: -3.3221169999999995, Min Reward: -0.0346620000, Max Reward: -0.0283460000, Average Reward: -0.03322117
# Episode 163/1000, Total Reward: -3.1764019999999995, Min Reward: -0.0351730000, Max Reward: -0.0264360000, Average Reward: -0.03176402000000001
# Episode 164/1000, Total Reward: -3.1639979999999994, Min Reward: -0.0347700000, Max Reward: -0.0263690000, Average Reward: -0.03163998
# Episode 165/1000, Total Reward: -3.1851599999999993, Min Reward: -0.0345130000, Max Reward: -0.0263300000, Average Reward: -0.0318516
# Episode 166/1000, Total Reward: -3.310603, Min Reward: -0.0349340000, Max Reward: -0.0270280000, Average Reward: -0.033106029999999995
# Episode 167/1000, Total Reward: -3.1731479999999994, Min Reward: -0.0344430000, Max Reward: -0.0265130000, Average Reward: -0.03173148
# Episode 168/1000, Total Reward: -3.146524999999999, Min Reward: -0.0343840000, Max Reward: -0.0263920000, Average Reward: -0.03146525000000001
# Episode 169/1000, Total Reward: -3.267315000000001, Min Reward: -0.0344890000, Max Reward: -0.0265460000, Average Reward: -0.03267315
# Episode 170/1000, Total Reward: -3.207054, Min Reward: -0.0349210000, Max Reward: -0.0265600000, Average Reward: -0.03207054
# Episode 171/1000, Total Reward: -3.172078000000001, Min Reward: -0.0345820000, Max Reward: -0.0264230000, Average Reward: -0.031720780000000004
# Episode 172/1000, Total Reward: -3.151707999999998, Min Reward: -0.0347030000, Max Reward: -0.0264720000, Average Reward: -0.031517079999999996
# Episode 173/1000, Total Reward: -3.3289559999999994, Min Reward: -0.0350810000, Max Reward: -0.0283500000, Average Reward: -0.03328956000000001
# Episode 174/1000, Total Reward: -3.164442999999999, Min Reward: -0.0348430000, Max Reward: -0.0263760000, Average Reward: -0.031644429999999994
# Episode 175/1000, Total Reward: -3.170121000000001, Min Reward: -0.0352110000, Max Reward: -0.0263260000, Average Reward: -0.03170121
# Episode 176/1000, Total Reward: -3.24913, Min Reward: -0.0347560000, Max Reward: -0.0263490000, Average Reward: -0.0324913
# Episode 177/1000, Total Reward: -3.2544779999999998, Min Reward: -0.0343180000, Max Reward: -0.0266950000, Average Reward: -0.032544779999999995
# Episode 178/1000, Total Reward: -3.1577380000000006, Min Reward: -0.0349190000, Max Reward: -0.0263430000, Average Reward: -0.03157738
# Episode 179/1000, Total Reward: -3.180814000000001, Min Reward: -0.0344810000, Max Reward: -0.0266180000, Average Reward: -0.03180814
# Episode 180/1000, Total Reward: -3.348934999999999, Min Reward: -0.0347350000, Max Reward: -0.0281370000, Average Reward: -0.033489349999999994
# Episode 181/1000, Total Reward: -3.167733999999999, Min Reward: -0.0346040000, Max Reward: -0.0262540000, Average Reward: -0.031677340000000005
# Episode 182/1000, Total Reward: -3.1556450000000007, Min Reward: -0.0346710000, Max Reward: -0.0263650000, Average Reward: -0.03155645
# Episode 183/1000, Total Reward: -3.2131459999999996, Min Reward: -0.0352350000, Max Reward: -0.0265460000, Average Reward: -0.032131459999999994
# Episode 184/1000, Total Reward: -3.3202580000000017, Min Reward: -0.0348740000, Max Reward: -0.0270240000, Average Reward: -0.03320258000000001
# Episode 185/1000, Total Reward: -3.1718069999999985, Min Reward: -0.0347150000, Max Reward: -0.0264180000, Average Reward: -0.03171807
# Episode 186/1000, Total Reward: -3.181705999999998, Min Reward: -0.0346700000, Max Reward: -0.0265510000, Average Reward: -0.03181706
# Episode 187/1000, Total Reward: -3.2989120000000005, Min Reward: -0.0348750000, Max Reward: -0.0265600000, Average Reward: -0.032989120000000004
# Episode 188/1000, Total Reward: -3.2399250000000004, Min Reward: -0.0347840000, Max Reward: -0.0263910000, Average Reward: -0.032399250000000004
# Episode 189/1000, Total Reward: -3.1806680000000007, Min Reward: -0.0347950000, Max Reward: -0.0263880000, Average Reward: -0.03180668
# Episode 190/1000, Total Reward: -3.1774170000000006, Min Reward: -0.0347550000, Max Reward: -0.0265970000, Average Reward: -0.031774170000000004
# Episode 191/1000, Total Reward: -3.335106, Min Reward: -0.0348460000, Max Reward: -0.0277640000, Average Reward: -0.033351059999999995
# Episode 192/1000, Total Reward: -3.1914630000000006, Min Reward: -0.0354710000, Max Reward: -0.0263740000, Average Reward: -0.03191463
# Episode 193/1000, Total Reward: -3.194037000000001, Min Reward: -0.0346170000, Max Reward: -0.0265510000, Average Reward: -0.03194037
# Episode 194/1000, Total Reward: -3.1817979999999983, Min Reward: -0.0349420000, Max Reward: -0.0265330000, Average Reward: -0.03181798
# Episode 195/1000, Total Reward: -3.319314, Min Reward: -0.0343850000, Max Reward: -0.0302530000, Average Reward: -0.033193139999999996
# Episode 196/1000, Total Reward: -3.1791540000000005, Min Reward: -0.0346440000, Max Reward: -0.0265880000, Average Reward: -0.03179154
# Episode 197/1000, Total Reward: -3.1939900000000017, Min Reward: -0.0349970000, Max Reward: -0.0265200000, Average Reward: -0.03193990000000001
# Episode 198/1000, Total Reward: -3.245258999999998, Min Reward: -0.0346610000, Max Reward: -0.0263940000, Average Reward: -0.032452589999999996
# Episode 199/1000, Total Reward: -3.2667469999999996, Min Reward: -0.0345970000, Max Reward: -0.0270280000, Average Reward: -0.032667470000000004
# Episode 200/1000, Total Reward: -3.1628640000000012, Min Reward: -0.0344530000, Max Reward: -0.0265020000, Average Reward: -0.03162864
# Episode 201/1000, Total Reward: -3.1947460000000003, Min Reward: -0.0347050000, Max Reward: -0.0264000000, Average Reward: -0.03194746
# Episode 202/1000, Total Reward: -3.310401, Min Reward: -0.0345350000, Max Reward: -0.0276580000, Average Reward: -0.03310401
# Episode 203/1000, Total Reward: -3.2096669999999987, Min Reward: -0.0352750000, Max Reward: -0.0264510000, Average Reward: -0.03209667
# Episode 204/1000, Total Reward: -3.174294999999999, Min Reward: -0.0345190000, Max Reward: -0.0264430000, Average Reward: -0.03174295
# Episode 205/1000, Total Reward: -3.1581940000000004, Min Reward: -0.0344410000, Max Reward: -0.0263900000, Average Reward: -0.03158194
# Episode 206/1000, Total Reward: -3.338113999999999, Min Reward: -0.0347060000, Max Reward: -0.0281180000, Average Reward: -0.033381140000000004
# Episode 207/1000, Total Reward: -3.165710000000001, Min Reward: -0.0345200000, Max Reward: -0.0264170000, Average Reward: -0.0316571
# Episode 208/1000, Total Reward: -3.1514899999999977, Min Reward: -0.0344610000, Max Reward: -0.0263710000, Average Reward: -0.0315149
# Episode 209/1000, Total Reward: -3.2619950000000006, Min Reward: -0.0347470000, Max Reward: -0.0264800000, Average Reward: -0.032619949999999995
# Episode 210/1000, Total Reward: -3.2618509999999996, Min Reward: -0.0346720000, Max Reward: -0.0266320000, Average Reward: -0.03261851
# Episode 211/1000, Total Reward: -3.167439, Min Reward: -0.0351970000, Max Reward: -0.0264660000, Average Reward: -0.03167439
# Episode 212/1000, Total Reward: -3.1742390000000005, Min Reward: -0.0346680000, Max Reward: -0.0263210000, Average Reward: -0.03174239
# Episode 213/1000, Total Reward: -3.354768, Min Reward: -0.0351570000, Max Reward: -0.0274710000, Average Reward: -0.03354768
# Episode 214/1000, Total Reward: -3.1876249999999997, Min Reward: -0.0350290000, Max Reward: -0.0264120000, Average Reward: -0.031876249999999995
# Episode 215/1000, Total Reward: -3.1671180000000008, Min Reward: -0.0345960000, Max Reward: -0.0264360000, Average Reward: -0.03167118000000001
# Episode 216/1000, Total Reward: -3.196584999999999, Min Reward: -0.0344650000, Max Reward: -0.0264430000, Average Reward: -0.031965850000000004
# Episode 217/1000, Total Reward: -3.312074, Min Reward: -0.0347080000, Max Reward: -0.0272920000, Average Reward: -0.03312074
# Episode 218/1000, Total Reward: -3.146934, Min Reward: -0.0350010000, Max Reward: -0.0263350000, Average Reward: -0.031469340000000005
# Episode 219/1000, Total Reward: -3.157623000000001, Min Reward: -0.0345950000, Max Reward: -0.0263460000, Average Reward: -0.031576230000000004
# Episode 220/1000, Total Reward: -3.293642, Min Reward: -0.0345720000, Max Reward: -0.0264520000, Average Reward: -0.03293642
# Episode 221/1000, Total Reward: -3.2227280000000023, Min Reward: -0.0372650000, Max Reward: -0.0265220000, Average Reward: -0.03222728
# Episode 222/1000, Total Reward: -3.1709789999999995, Min Reward: -0.0374280000, Max Reward: -0.0264340000, Average Reward: -0.03170979
# Episode 223/1000, Total Reward: -3.1671849999999995, Min Reward: -0.0345120000, Max Reward: -0.0265800000, Average Reward: -0.03167185
# Episode 224/1000, Total Reward: -3.326880000000001, Min Reward: -0.0345420000, Max Reward: -0.0271880000, Average Reward: -0.033268799999999994
# Episode 225/1000, Total Reward: -3.1674199999999995, Min Reward: -0.0347300000, Max Reward: -0.0264830000, Average Reward: -0.0316742
# Episode 226/1000, Total Reward: -3.1954459999999996, Min Reward: -0.0347540000, Max Reward: -0.0265520000, Average Reward: -0.03195446
# Episode 227/1000, Total Reward: -3.212914, Min Reward: -0.0347140000, Max Reward: -0.0263260000, Average Reward: -0.03212914
# Episode 228/1000, Total Reward: -3.329193, Min Reward: -0.0351860000, Max Reward: -0.0268010000, Average Reward: -0.03329193
# Episode 229/1000, Total Reward: -3.16709, Min Reward: -0.0347040000, Max Reward: -0.0265190000, Average Reward: -0.031670899999999995
# Episode 230/1000, Total Reward: -3.1842700000000006, Min Reward: -0.0355140000, Max Reward: -0.0263500000, Average Reward: -0.031842699999999995
# Episode 231/1000, Total Reward: -3.279922999999999, Min Reward: -0.0350220000, Max Reward: -0.0264480000, Average Reward: -0.03279923
# Episode 232/1000, Total Reward: -3.2236049999999996, Min Reward: -0.0347670000, Max Reward: -0.0263500000, Average Reward: -0.032236049999999995
# Episode 233/1000, Total Reward: -3.183207000000001, Min Reward: -0.0345900000, Max Reward: -0.0264290000, Average Reward: -0.031832070000000004
# Episode 234/1000, Total Reward: -3.1723030000000008, Min Reward: -0.0346860000, Max Reward: -0.0263420000, Average Reward: -0.03172303
# Episode 235/1000, Total Reward: -3.3236719999999997, Min Reward: -0.0348190000, Max Reward: -0.0281010000, Average Reward: -0.03323672
# Episode 236/1000, Total Reward: -3.1711020000000003, Min Reward: -0.0346090000, Max Reward: -0.0264810000, Average Reward: -0.031711020000000006
# Episode 237/1000, Total Reward: -3.169222999999999, Min Reward: -0.0348990000, Max Reward: -0.0264950000, Average Reward: -0.03169223
# Episode 238/1000, Total Reward: -3.2183960000000007, Min Reward: -0.0343980000, Max Reward: -0.0263970000, Average Reward: -0.03218396
# Episode 239/1000, Total Reward: -3.2790860000000004, Min Reward: -0.0345610000, Max Reward: -0.0269190000, Average Reward: -0.03279086
# Episode 240/1000, Total Reward: -3.174310999999999, Min Reward: -0.0352970000, Max Reward: -0.0264200000, Average Reward: -0.03174311
# Episode 241/1000, Total Reward: -3.1464189999999994, Min Reward: -0.0344880000, Max Reward: -0.0263690000, Average Reward: -0.03146419
# Episode 242/1000, Total Reward: -3.3266390000000006, Min Reward: -0.0346050000, Max Reward: -0.0289920000, Average Reward: -0.03326639
# Episode 243/1000, Total Reward: -3.180292, Min Reward: -0.0349380000, Max Reward: -0.0262960000, Average Reward: -0.031802920000000005
# Episode 244/1000, Total Reward: -3.1508539999999994, Min Reward: -0.0347830000, Max Reward: -0.0263720000, Average Reward: -0.03150854
# Episode 245/1000, Total Reward: -3.19017, Min Reward: -0.0349190000, Max Reward: -0.0264530000, Average Reward: -0.0319017
# Episode 246/1000, Total Reward: -3.311209, Min Reward: -0.0349450000, Max Reward: -0.0270670000, Average Reward: -0.033112090000000004
# Episode 247/1000, Total Reward: -3.1690310000000004, Min Reward: -0.0374870000, Max Reward: -0.0265000000, Average Reward: -0.031690310000000006
# Episode 248/1000, Total Reward: -3.158905999999999, Min Reward: -0.0344210000, Max Reward: -0.0265100000, Average Reward: -0.03158906
# Episode 249/1000, Total Reward: -3.279913, Min Reward: -0.0347840000, Max Reward: -0.0270740000, Average Reward: -0.03279913
# Episode 250/1000, Total Reward: -3.1822650000000006, Min Reward: -0.0345330000, Max Reward: -0.0264730000, Average Reward: -0.03182265
# Episode 251/1000, Total Reward: -3.168861, Min Reward: -0.0345310000, Max Reward: -0.0263730000, Average Reward: -0.03168861
# Episode 252/1000, Total Reward: -3.1567009999999995, Min Reward: -0.0346810000, Max Reward: -0.0264450000, Average Reward: -0.031567010000000006
# Episode 253/1000, Total Reward: -3.3377369999999997, Min Reward: -0.0349280000, Max Reward: -0.0287080000, Average Reward: -0.03337737
# Episode 254/1000, Total Reward: -3.1632829999999976, Min Reward: -0.0343090000, Max Reward: -0.0265080000, Average Reward: -0.03163283
# Episode 255/1000, Total Reward: -3.166167000000002, Min Reward: -0.0345800000, Max Reward: -0.0263470000, Average Reward: -0.031661669999999996
# Episode 256/1000, Total Reward: -3.2699260000000026, Min Reward: -0.0346600000, Max Reward: -0.0263170000, Average Reward: -0.03269926
# Episode 257/1000, Total Reward: -3.2451379999999994, Min Reward: -0.0346710000, Max Reward: -0.0265600000, Average Reward: -0.03245138
# Episode 258/1000, Total Reward: -3.143647, Min Reward: -0.0345310000, Max Reward: -0.0263170000, Average Reward: -0.031436469999999994
# Episode 259/1000, Total Reward: -3.1515710000000015, Min Reward: -0.0345360000, Max Reward: -0.0264040000, Average Reward: -0.031515709999999995
# Episode 260/1000, Total Reward: -3.329082000000001, Min Reward: -0.0347250000, Max Reward: -0.0274850000, Average Reward: -0.033290820000000006
# Episode 261/1000, Total Reward: -3.1671189999999996, Min Reward: -0.0346060000, Max Reward: -0.0264390000, Average Reward: -0.031671189999999995
# Episode 262/1000, Total Reward: -3.150792000000002, Min Reward: -0.0345380000, Max Reward: -0.0263580000, Average Reward: -0.031507919999999995
# Episode 263/1000, Total Reward: -3.227652, Min Reward: -0.0345220000, Max Reward: -0.0263910000, Average Reward: -0.032276519999999996
# Episode 264/1000, Total Reward: -3.2599200000000006, Min Reward: -0.0349170000, Max Reward: -0.0266570000, Average Reward: -0.032599199999999995
# Episode 265/1000, Total Reward: -3.1534380000000013, Min Reward: -0.0346090000, Max Reward: -0.0263590000, Average Reward: -0.03153438
# Episode 266/1000, Total Reward: -3.1833220000000013, Min Reward: -0.0350330000, Max Reward: -0.0264680000, Average Reward: -0.03183322
# Episode 267/1000, Total Reward: -3.3352579999999983, Min Reward: -0.0345490000, Max Reward: -0.0297680000, Average Reward: -0.03335258
# Episode 268/1000, Total Reward: -3.1580200000000005, Min Reward: -0.0347490000, Max Reward: -0.0263150000, Average Reward: -0.0315802
# Episode 269/1000, Total Reward: -3.183379, Min Reward: -0.0348530000, Max Reward: -0.0263590000, Average Reward: -0.03183379
# Episode 270/1000, Total Reward: -3.1930499999999995, Min Reward: -0.0351100000, Max Reward: -0.0264830000, Average Reward: -0.0319305
# Episode 271/1000, Total Reward: -3.315413, Min Reward: -0.0346890000, Max Reward: -0.0272980000, Average Reward: -0.03315413
# Episode 272/1000, Total Reward: -3.1627439999999987, Min Reward: -0.0344270000, Max Reward: -0.0263970000, Average Reward: -0.03162743999999999
# Episode 273/1000, Total Reward: -3.1501129999999993, Min Reward: -0.0344120000, Max Reward: -0.0263760000, Average Reward: -0.031501129999999995
# Episode 274/1000, Total Reward: -3.3045309999999986, Min Reward: -0.0345990000, Max Reward: -0.0265730000, Average Reward: -0.03304531
# Episode 275/1000, Total Reward: -3.1912900000000004, Min Reward: -0.0344710000, Max Reward: -0.0264280000, Average Reward: -0.0319129
# Episode 276/1000, Total Reward: -3.162433999999999, Min Reward: -0.0348160000, Max Reward: -0.0264220000, Average Reward: -0.03162434
# Episode 277/1000, Total Reward: -3.176968000000001, Min Reward: -0.0349010000, Max Reward: -0.0264710000, Average Reward: -0.03176968
# Episode 278/1000, Total Reward: -3.3270799999999996, Min Reward: -0.0344730000, Max Reward: -0.0272940000, Average Reward: -0.0332708
# Episode 279/1000, Total Reward: -3.1753160000000005, Min Reward: -0.0344400000, Max Reward: -0.0263640000, Average Reward: -0.03175316
# Episode 280/1000, Total Reward: -3.151428000000001, Min Reward: -0.0344310000, Max Reward: -0.0264050000, Average Reward: -0.03151428
# Episode 281/1000, Total Reward: -3.2851350000000004, Min Reward: -0.0344990000, Max Reward: -0.0265140000, Average Reward: -0.03285135
# Episode 282/1000, Total Reward: -3.217228, Min Reward: -0.0349810000, Max Reward: -0.0264440000, Average Reward: -0.03217228
# Episode 283/1000, Total Reward: -3.143801, Min Reward: -0.0347730000, Max Reward: -0.0262430000, Average Reward: -0.03143801
# Episode 284/1000, Total Reward: -3.151279999999999, Min Reward: -0.0346280000, Max Reward: -0.0262900000, Average Reward: -0.0315128
# Episode 285/1000, Total Reward: -3.3118199999999995, Min Reward: -0.0347560000, Max Reward: -0.0271770000, Average Reward: -0.033118199999999993
# Episode 286/1000, Total Reward: -3.1653699999999994, Min Reward: -0.0346290000, Max Reward: -0.0264030000, Average Reward: -0.0316537
# Episode 287/1000, Total Reward: -3.17845, Min Reward: -0.0346860000, Max Reward: -0.0264020000, Average Reward: -0.0317845
# Episode 288/1000, Total Reward: -3.2378599999999995, Min Reward: -0.0346680000, Max Reward: -0.0265010000, Average Reward: -0.0323786
# Episode 289/1000, Total Reward: -3.2461800000000007, Min Reward: -0.0348680000, Max Reward: -0.0266480000, Average Reward: -0.032461800000000006
# Episode 290/1000, Total Reward: -3.1510059999999993, Min Reward: -0.0346210000, Max Reward: -0.0263600000, Average Reward: -0.03151006
# Episode 291/1000, Total Reward: -3.1554359999999995, Min Reward: -0.0342100000, Max Reward: -0.0265210000, Average Reward: -0.03155436
# Episode 292/1000, Total Reward: -3.3175690000000007, Min Reward: -0.0348350000, Max Reward: -0.0279040000, Average Reward: -0.03317569
# Episode 293/1000, Total Reward: -3.1514940000000013, Min Reward: -0.0344320000, Max Reward: -0.0262720000, Average Reward: -0.03151494
# Episode 294/1000, Total Reward: -3.155928999999999, Min Reward: -0.0346330000, Max Reward: -0.0263630000, Average Reward: -0.03155929
# Episode 295/1000, Total Reward: -3.2208709999999985, Min Reward: -0.0346690000, Max Reward: -0.0264190000, Average Reward: -0.03220871
# Episode 296/1000, Total Reward: -3.247836999999999, Min Reward: -0.0345530000, Max Reward: -0.0265500000, Average Reward: -0.03247837
# Episode 297/1000, Total Reward: -3.157791, Min Reward: -0.0351080000, Max Reward: -0.0262900000, Average Reward: -0.03157791000000001
# Episode 298/1000, Total Reward: -3.1555099999999996, Min Reward: -0.0346440000, Max Reward: -0.0263530000, Average Reward: -0.0315551
# Episode 299/1000, Total Reward: -3.322406999999999, Min Reward: -0.0348740000, Max Reward: -0.0282670000, Average Reward: -0.03322407
# Episode 300/1000, Total Reward: -3.168491000000001, Min Reward: -0.0352210000, Max Reward: -0.0266030000, Average Reward: -0.031684910000000004
# Episode 301/1000, Total Reward: -3.1544380000000003, Min Reward: -0.0344210000, Max Reward: -0.0262440000, Average Reward: -0.03154438
# Episode 302/1000, Total Reward: -3.237956999999999, Min Reward: -0.0348950000, Max Reward: -0.0263410000, Average Reward: -0.03237957
# Episode 303/1000, Total Reward: -3.2459249999999997, Min Reward: -0.0345170000, Max Reward: -0.0265920000, Average Reward: -0.032459249999999995
# Episode 304/1000, Total Reward: -3.164526999999999, Min Reward: -0.0347440000, Max Reward: -0.0264480000, Average Reward: -0.03164527
# Episode 305/1000, Total Reward: -3.151596000000001, Min Reward: -0.0344060000, Max Reward: -0.0263000000, Average Reward: -0.03151596
# Episode 306/1000, Total Reward: -3.3053560000000006, Min Reward: -0.0350380000, Max Reward: -0.0275060000, Average Reward: -0.03305356
# Episode 307/1000, Total Reward: -3.1562569999999988, Min Reward: -0.0342640000, Max Reward: -0.0265070000, Average Reward: -0.03156257
# Episode 308/1000, Total Reward: -3.1589210000000003, Min Reward: -0.0346970000, Max Reward: -0.0264160000, Average Reward: -0.03158920999999999
# Episode 309/1000, Total Reward: -3.2462459999999984, Min Reward: -0.0348910000, Max Reward: -0.0262770000, Average Reward: -0.03246246
# Episode 310/1000, Total Reward: -3.2860819999999995, Min Reward: -0.0374160000, Max Reward: -0.0264470000, Average Reward: -0.03286082
# Episode 311/1000, Total Reward: -3.155404999999999, Min Reward: -0.0374800000, Max Reward: -0.0263110000, Average Reward: -0.03155404999999999
# Episode 312/1000, Total Reward: -3.157100999999999, Min Reward: -0.0350400000, Max Reward: -0.0264120000, Average Reward: -0.03157101
# Episode 313/1000, Total Reward: -3.3034989999999995, Min Reward: -0.0348610000, Max Reward: -0.0271720000, Average Reward: -0.03303499000000001
# Episode 314/1000, Total Reward: -3.172029000000001, Min Reward: -0.0342620000, Max Reward: -0.0263760000, Average Reward: -0.03172029
# Episode 315/1000, Total Reward: -3.156847999999999, Min Reward: -0.0346760000, Max Reward: -0.0263230000, Average Reward: -0.03156848
# Episode 316/1000, Total Reward: -3.188461, Min Reward: -0.0345830000, Max Reward: -0.0264360000, Average Reward: -0.03188461
# Episode 317/1000, Total Reward: -3.315995000000001, Min Reward: -0.0345900000, Max Reward: -0.0271580000, Average Reward: -0.03315995
# Episode 318/1000, Total Reward: -3.1627520000000007, Min Reward: -0.0345290000, Max Reward: -0.0264040000, Average Reward: -0.03162752
# Episode 319/1000, Total Reward: -3.149129, Min Reward: -0.0345660000, Max Reward: -0.0264700000, Average Reward: -0.03149129
# Episode 320/1000, Total Reward: -3.303707000000001, Min Reward: -0.0344820000, Max Reward: -0.0265390000, Average Reward: -0.033037069999999995
# Episode 321/1000, Total Reward: -3.211654999999998, Min Reward: -0.0347660000, Max Reward: -0.0263400000, Average Reward: -0.03211655
# Episode 322/1000, Total Reward: -3.1379030000000006, Min Reward: -0.0353980000, Max Reward: -0.0263860000, Average Reward: -0.031379029999999995
# Episode 323/1000, Total Reward: -3.151968999999999, Min Reward: -0.0344970000, Max Reward: -0.0264250000, Average Reward: -0.031519689999999996
# Episode 324/1000, Total Reward: -3.3210749999999987, Min Reward: -0.0349460000, Max Reward: -0.0277900000, Average Reward: -0.03321075
# Episode 325/1000, Total Reward: -3.157021999999999, Min Reward: -0.0345250000, Max Reward: -0.0263250000, Average Reward: -0.031570219999999996
# Episode 326/1000, Total Reward: -3.1655499999999996, Min Reward: -0.0345190000, Max Reward: -0.0264440000, Average Reward: -0.0316555
# Episode 327/1000, Total Reward: -3.27831, Min Reward: -0.0347900000, Max Reward: -0.0266290000, Average Reward: -0.03278310000000001
# Episode 328/1000, Total Reward: -3.223492, Min Reward: -0.0346230000, Max Reward: -0.0265060000, Average Reward: -0.03223492
# Episode 329/1000, Total Reward: -3.1613439999999997, Min Reward: -0.0349280000, Max Reward: -0.0263640000, Average Reward: -0.03161344
# Episode 330/1000, Total Reward: -3.1467510000000014, Min Reward: -0.0342760000, Max Reward: -0.0264000000, Average Reward: -0.031467510000000004
# Episode 331/1000, Total Reward: -3.324158, Min Reward: -0.0346350000, Max Reward: -0.0283480000, Average Reward: -0.03324158000000001
# Episode 332/1000, Total Reward: -3.1491710000000004, Min Reward: -0.0349380000, Max Reward: -0.0263010000, Average Reward: -0.03149171
# Episode 333/1000, Total Reward: -3.160684, Min Reward: -0.0349100000, Max Reward: -0.0264570000, Average Reward: -0.031606840000000004
# Episode 334/1000, Total Reward: -3.235750999999999, Min Reward: -0.0345560000, Max Reward: -0.0264510000, Average Reward: -0.03235751
# Episode 335/1000, Total Reward: -3.247079000000001, Min Reward: -0.0348580000, Max Reward: -0.0270340000, Average Reward: -0.03247079
# Episode 336/1000, Total Reward: -3.1847369999999993, Min Reward: -0.0360280000, Max Reward: -0.0264970000, Average Reward: -0.03184736999999999
# Episode 337/1000, Total Reward: -3.1604639999999997, Min Reward: -0.0346660000, Max Reward: -0.0263360000, Average Reward: -0.031604639999999996
# Episode 338/1000, Total Reward: -3.327298, Min Reward: -0.0351550000, Max Reward: -0.0278280000, Average Reward: -0.03327298
# Episode 339/1000, Total Reward: -3.155810999999999, Min Reward: -0.0346620000, Max Reward: -0.0262450000, Average Reward: -0.03155811
# Episode 340/1000, Total Reward: -3.166111000000001, Min Reward: -0.0350160000, Max Reward: -0.0264240000, Average Reward: -0.03166111
# Episode 341/1000, Total Reward: -3.1794499999999997, Min Reward: -0.0345520000, Max Reward: -0.0264130000, Average Reward: -0.0317945
# Episode 342/1000, Total Reward: -3.2963100000000005, Min Reward: -0.0346990000, Max Reward: -0.0269840000, Average Reward: -0.0329631
# Episode 343/1000, Total Reward: -3.1656150000000003, Min Reward: -0.0346470000, Max Reward: -0.0265160000, Average Reward: -0.03165615
# Episode 344/1000, Total Reward: -3.168375999999999, Min Reward: -0.0346740000, Max Reward: -0.0263800000, Average Reward: -0.03168375999999999
# Episode 345/1000, Total Reward: -3.2906440000000003, Min Reward: -0.0347430000, Max Reward: -0.0264730000, Average Reward: -0.03290644
# Episode 346/1000, Total Reward: -3.1867550000000002, Min Reward: -0.0349460000, Max Reward: -0.0263960000, Average Reward: -0.03186755
# Episode 347/1000, Total Reward: -3.144592, Min Reward: -0.0343520000, Max Reward: -0.0263260000, Average Reward: -0.03144592
# Episode 348/1000, Total Reward: -3.1616099999999996, Min Reward: -0.0345500000, Max Reward: -0.0263490000, Average Reward: -0.0316161
# Episode 349/1000, Total Reward: -3.3123100000000014, Min Reward: -0.0348450000, Max Reward: -0.0270960000, Average Reward: -0.0331231
# Episode 350/1000, Total Reward: -3.1633739999999997, Min Reward: -0.0350090000, Max Reward: -0.0262780000, Average Reward: -0.031633739999999994
# Episode 351/1000, Total Reward: -3.1546420000000004, Min Reward: -0.0344400000, Max Reward: -0.0263210000, Average Reward: -0.03154642
# Episode 352/1000, Total Reward: -3.2703569999999997, Min Reward: -0.0350220000, Max Reward: -0.0264530000, Average Reward: -0.032703569999999994
# ...
# Episode 884/1000, Total Reward: -3.1675079999999998, Min Reward: -0.0345710000, Max Reward: -0.0263290000, Average Reward: -0.031675079999999994
# Episode 885/1000, Total Reward: -3.215453999999999, Min Reward: -0.0349040000, Max Reward: -0.0264790000, Average Reward: -0.032154539999999995
# Episode 886/1000, Total Reward: -3.2947569999999997, Min Reward: -0.0352140000, Max Reward: -0.0267560000, Average Reward: -0.03294757000000001
# Episode 887/1000, Total Reward: -3.172015, Min Reward: -0.0348310000, Max Reward: -0.0264860000, Average Reward: -0.03172015
# Episode 888/1000, Total Reward: -3.1709550000000006, Min Reward: -0.0346340000, Max Reward: -0.0263740000, Average Reward: -0.03170955
# Episode 889/1000, Total Reward: -3.2883290000000005, Min Reward: -0.0346870000, Max Reward: -0.0264050000, Average Reward: -0.03288329
# Episode 890/1000, Total Reward: -3.215717, Min Reward: -0.0347250000, Max Reward: -0.0263770000, Average Reward: -0.032157170000000006
# Episode 891/1000, Total Reward: -3.1616740000000005, Min Reward: -0.0346500000, Max Reward: -0.0263480000, Average Reward: -0.031616740000000004
# Episode 892/1000, Total Reward: -3.163153000000001, Min Reward: -0.0345410000, Max Reward: -0.0264160000, Average Reward: -0.03163153
# Episode 893/1000, Total Reward: -3.319954000000001, Min Reward: -0.0347200000, Max Reward: -0.0281830000, Average Reward: -0.03319954
# Episode 894/1000, Total Reward: -3.1551000000000013, Min Reward: -0.0349600000, Max Reward: -0.0262550000, Average Reward: -0.031551
# Episode 895/1000, Total Reward: -3.1739740000000003, Min Reward: -0.0348830000, Max Reward: -0.0262680000, Average Reward: -0.03173974
# Episode 896/1000, Total Reward: -3.224454000000001, Min Reward: -0.0346880000, Max Reward: -0.0263730000, Average Reward: -0.03224454
# Episode 897/1000, Total Reward: -3.2545659999999987, Min Reward: -0.0345300000, Max Reward: -0.0265460000, Average Reward: -0.032545660000000004
# Episode 898/1000, Total Reward: -3.170543999999999, Min Reward: -0.0354260000, Max Reward: -0.0264060000, Average Reward: -0.03170544
# Episode 899/1000, Total Reward: -3.168364999999999, Min Reward: -0.0346720000, Max Reward: -0.0263970000, Average Reward: -0.031683649999999994
# Episode 900/1000, Total Reward: -3.3223309999999997, Min Reward: -0.0345710000, Max Reward: -0.0276770000, Average Reward: -0.03322331
# Episode 901/1000, Total Reward: -3.1727850000000006, Min Reward: -0.0349950000, Max Reward: -0.0265280000, Average Reward: -0.031727849999999995
# Episode 902/1000, Total Reward: -3.1669140000000016, Min Reward: -0.0347120000, Max Reward: -0.0264820000, Average Reward: -0.03166914
# Episode 903/1000, Total Reward: -3.186919000000001, Min Reward: -0.0346850000, Max Reward: -0.0263530000, Average Reward: -0.03186919
# Episode 904/1000, Total Reward: -3.325041, Min Reward: -0.0345920000, Max Reward: -0.0273030000, Average Reward: -0.033250409999999994
# Episode 905/1000, Total Reward: -3.1729000000000016, Min Reward: -0.0345430000, Max Reward: -0.0264230000, Average Reward: -0.031729
# Episode 906/1000, Total Reward: -3.165351000000002, Min Reward: -0.0348080000, Max Reward: -0.0264310000, Average Reward: -0.031653509999999996
# Episode 907/1000, Total Reward: -3.2725180000000003, Min Reward: -0.0345050000, Max Reward: -0.0267710000, Average Reward: -0.03272518
# Episode 908/1000, Total Reward: -3.2123180000000007, Min Reward: -0.0347120000, Max Reward: -0.0264900000, Average Reward: -0.032123179999999994
# Episode 909/1000, Total Reward: -3.157339000000001, Min Reward: -0.0346400000, Max Reward: -0.0264790000, Average Reward: -0.03157338999999999
# Episode 910/1000, Total Reward: -3.1631009999999993, Min Reward: -0.0346730000, Max Reward: -0.0264550000, Average Reward: -0.03163101000000001
# Episode 911/1000, Total Reward: -3.334894999999999, Min Reward: -0.0351150000, Max Reward: -0.0277560000, Average Reward: -0.03334895
# Episode 912/1000, Total Reward: -3.182034, Min Reward: -0.0345760000, Max Reward: -0.0263990000, Average Reward: -0.03182034
# Episode 913/1000, Total Reward: -3.172399999999999, Min Reward: -0.0345700000, Max Reward: -0.0263310000, Average Reward: -0.031723999999999995
# Episode 914/1000, Total Reward: -3.212022999999999, Min Reward: -0.0349250000, Max Reward: -0.0264430000, Average Reward: -0.03212023
# Episode 915/1000, Total Reward: -3.2992570000000008, Min Reward: -0.0345160000, Max Reward: -0.0270550000, Average Reward: -0.03299257
# Episode 916/1000, Total Reward: -3.165076, Min Reward: -0.0344020000, Max Reward: -0.0265440000, Average Reward: -0.03165076
# Episode 917/1000, Total Reward: -3.169004999999999, Min Reward: -0.0350040000, Max Reward: -0.0264420000, Average Reward: -0.031690050000000004
# Episode 918/1000, Total Reward: -3.314580000000001, Min Reward: -0.0346270000, Max Reward: -0.0268730000, Average Reward: -0.0331458
# Episode 919/1000, Total Reward: -3.188369000000001, Min Reward: -0.0344570000, Max Reward: -0.0264250000, Average Reward: -0.03188369
# Episode 920/1000, Total Reward: -3.1736269999999998, Min Reward: -0.0345760000, Max Reward: -0.0263130000, Average Reward: -0.03173626999999999
# Episode 921/1000, Total Reward: -3.1788180000000006, Min Reward: -0.0347220000, Max Reward: -0.0263720000, Average Reward: -0.03178818
# Episode 922/1000, Total Reward: -3.3454560000000004, Min Reward: -0.0346630000, Max Reward: -0.0275140000, Average Reward: -0.03345456
# Episode 923/1000, Total Reward: -3.179395, Min Reward: -0.0348450000, Max Reward: -0.0263400000, Average Reward: -0.03179395
# Episode 924/1000, Total Reward: -3.1720669999999997, Min Reward: -0.0351280000, Max Reward: -0.0263550000, Average Reward: -0.03172067
# Episode 925/1000, Total Reward: -3.22674, Min Reward: -0.0347610000, Max Reward: -0.0264440000, Average Reward: -0.0322674
# Episode 926/1000, Total Reward: -3.2760199999999995, Min Reward: -0.0348520000, Max Reward: -0.0270680000, Average Reward: -0.032760199999999996
# Episode 927/1000, Total Reward: -3.160327, Min Reward: -0.0344290000, Max Reward: -0.0264010000, Average Reward: -0.03160327
# Episode 928/1000, Total Reward: -3.162058000000001, Min Reward: -0.0345240000, Max Reward: -0.0265410000, Average Reward: -0.03162058
# Episode 929/1000, Total Reward: -3.3034829999999995, Min Reward: -0.0344960000, Max Reward: -0.0268900000, Average Reward: -0.03303483
# Episode 930/1000, Total Reward: -3.1833049999999994, Min Reward: -0.0345270000, Max Reward: -0.0264240000, Average Reward: -0.03183305
# Episode 931/1000, Total Reward: -3.1643999999999997, Min Reward: -0.0346680000, Max Reward: -0.0264060000, Average Reward: -0.031644000000000005
# Episode 932/1000, Total Reward: -3.1618749999999998, Min Reward: -0.0346520000, Max Reward: -0.0263980000, Average Reward: -0.03161875
# Episode 933/1000, Total Reward: -3.3435109999999986, Min Reward: -0.0350790000, Max Reward: -0.0288870000, Average Reward: -0.03343511
# Episode 934/1000, Total Reward: -3.1738720000000007, Min Reward: -0.0350790000, Max Reward: -0.0264490000, Average Reward: -0.031738720000000005
# Episode 935/1000, Total Reward: -3.168707, Min Reward: -0.0348620000, Max Reward: -0.0264430000, Average Reward: -0.03168707
# Episode 936/1000, Total Reward: -3.242196999999999, Min Reward: -0.0350390000, Max Reward: -0.0265300000, Average Reward: -0.03242197000000001
# Episode 937/1000, Total Reward: -3.2578489999999998, Min Reward: -0.0344950000, Max Reward: -0.0267280000, Average Reward: -0.032578489999999995
# Episode 938/1000, Total Reward: -3.172543, Min Reward: -0.0447280000, Max Reward: -0.0263640000, Average Reward: -0.03172543
# Episode 939/1000, Total Reward: -3.152439999999999, Min Reward: -0.0348760000, Max Reward: -0.0262710000, Average Reward: -0.0315244
# Episode 940/1000, Total Reward: -3.3307069999999985, Min Reward: -0.0348540000, Max Reward: -0.0279660000, Average Reward: -0.03330707
# Episode 941/1000, Total Reward: -3.1679530000000002, Min Reward: -0.0344330000, Max Reward: -0.0264730000, Average Reward: -0.031679530000000004
# Episode 942/1000, Total Reward: -3.1647990000000004, Min Reward: -0.0344420000, Max Reward: -0.0263980000, Average Reward: -0.03164799
# Episode 943/1000, Total Reward: -3.180761, Min Reward: -0.0348710000, Max Reward: -0.0264860000, Average Reward: -0.03180761
# Episode 944/1000, Total Reward: -3.315497, Min Reward: -0.0347780000, Max Reward: -0.0272150000, Average Reward: -0.03315497
# Episode 945/1000, Total Reward: -3.1613990000000007, Min Reward: -0.0346010000, Max Reward: -0.0263110000, Average Reward: -0.03161399
# Episode 946/1000, Total Reward: -3.161924000000001, Min Reward: -0.0344340000, Max Reward: -0.0262860000, Average Reward: -0.03161924
# Episode 947/1000, Total Reward: -3.277733, Min Reward: -0.0346420000, Max Reward: -0.0266110000, Average Reward: -0.03277733
# Episode 948/1000, Total Reward: -3.2399400000000007, Min Reward: -0.0348950000, Max Reward: -0.0264370000, Average Reward: -0.032399399999999995
# Episode 949/1000, Total Reward: -3.1790800000000004, Min Reward: -0.0350910000, Max Reward: -0.0262980000, Average Reward: -0.031790799999999994
# Episode 950/1000, Total Reward: -3.1548850000000006, Min Reward: -0.0346960000, Max Reward: -0.0263230000, Average Reward: -0.03154885
# Episode 951/1000, Total Reward: -3.3122910000000005, Min Reward: -0.0346560000, Max Reward: -0.0271610000, Average Reward: -0.03312291
# Episode 952/1000, Total Reward: -3.1492309999999994, Min Reward: -0.0348680000, Max Reward: -0.0262880000, Average Reward: -0.031492309999999996
# Episode 953/1000, Total Reward: -3.152305999999999, Min Reward: -0.0350170000, Max Reward: -0.0263250000, Average Reward: -0.03152305999999999
# Episode 954/1000, Total Reward: -3.221317000000001, Min Reward: -0.0345870000, Max Reward: -0.0264400000, Average Reward: -0.032213170000000006
# Episode 955/1000, Total Reward: -3.249797, Min Reward: -0.0343740000, Max Reward: -0.0265080000, Average Reward: -0.03249797
# Episode 956/1000, Total Reward: -3.177178, Min Reward: -0.0343470000, Max Reward: -0.0264440000, Average Reward: -0.031771780000000006
# Episode 957/1000, Total Reward: -3.1627140000000002, Min Reward: -0.0348280000, Max Reward: -0.0262640000, Average Reward: -0.03162714
# Episode 958/1000, Total Reward: -3.337078999999999, Min Reward: -0.0344710000, Max Reward: -0.0273210000, Average Reward: -0.03337078999999999
# Episode 959/1000, Total Reward: -3.1761059999999994, Min Reward: -0.0349480000, Max Reward: -0.0265140000, Average Reward: -0.03176106
# Episode 960/1000, Total Reward: -3.175732999999999, Min Reward: -0.0347360000, Max Reward: -0.0265520000, Average Reward: -0.03175733
# Episode 961/1000, Total Reward: -3.190777999999999, Min Reward: -0.0342610000, Max Reward: -0.0264210000, Average Reward: -0.031907780000000004
# Episode 962/1000, Total Reward: -3.3086390000000003, Min Reward: -0.0351280000, Max Reward: -0.0272910000, Average Reward: -0.03308639
# Episode 963/1000, Total Reward: -3.153209000000001, Min Reward: -0.0344980000, Max Reward: -0.0264290000, Average Reward: -0.031532090000000006
# Episode 964/1000, Total Reward: -3.162267, Min Reward: -0.0347160000, Max Reward: -0.0263110000, Average Reward: -0.03162267
# Episode 965/1000, Total Reward: -3.292086, Min Reward: -0.0347230000, Max Reward: -0.0263780000, Average Reward: -0.032920859999999996
# Episode 966/1000, Total Reward: -3.189682, Min Reward: -0.0351100000, Max Reward: -0.0264190000, Average Reward: -0.03189682
# Episode 967/1000, Total Reward: -3.1460250000000003, Min Reward: -0.0346940000, Max Reward: -0.0263410000, Average Reward: -0.031460249999999995
# Episode 968/1000, Total Reward: -3.138748, Min Reward: -0.0342120000, Max Reward: -0.0263320000, Average Reward: -0.03138748
# Episode 969/1000, Total Reward: -3.3341080000000005, Min Reward: -0.0345220000, Max Reward: -0.0279820000, Average Reward: -0.03334108
# Episode 970/1000, Total Reward: -3.160508, Min Reward: -0.0345070000, Max Reward: -0.0264020000, Average Reward: -0.031605079999999994
# Episode 971/1000, Total Reward: -3.155935, Min Reward: -0.0350900000, Max Reward: -0.0263540000, Average Reward: -0.03155935
# Episode 972/1000, Total Reward: -3.2580520000000006, Min Reward: -0.0349330000, Max Reward: -0.0263640000, Average Reward: -0.032580519999999995
# Episode 973/1000, Total Reward: -3.2408459999999994, Min Reward: -0.0348090000, Max Reward: -0.0265270000, Average Reward: -0.03240846
# Episode 974/1000, Total Reward: -3.1459220000000014, Min Reward: -0.0343710000, Max Reward: -0.0264250000, Average Reward: -0.03145922
# Episode 975/1000, Total Reward: -3.178424999999999, Min Reward: -0.0353890000, Max Reward: -0.0264590000, Average Reward: -0.03178424999999999
# Episode 976/1000, Total Reward: -3.328801000000001, Min Reward: -0.0348240000, Max Reward: -0.0274780000, Average Reward: -0.03328800999999999
# Episode 977/1000, Total Reward: -3.162023, Min Reward: -0.0346400000, Max Reward: -0.0263510000, Average Reward: -0.03162023
# Episode 978/1000, Total Reward: -3.173471000000001, Min Reward: -0.0352950000, Max Reward: -0.0263970000, Average Reward: -0.031734710000000006
# Episode 979/1000, Total Reward: -3.198808000000001, Min Reward: -0.0342900000, Max Reward: -0.0263820000, Average Reward: -0.031988079999999995
# Episode 980/1000, Total Reward: -3.289875999999999, Min Reward: -0.0347330000, Max Reward: -0.0270990000, Average Reward: -0.03289876
# Episode 981/1000, Total Reward: -3.1694739999999992, Min Reward: -0.0348110000, Max Reward: -0.0265230000, Average Reward: -0.03169474
# Episode 982/1000, Total Reward: -3.167982999999998, Min Reward: -0.0347220000, Max Reward: -0.0264780000, Average Reward: -0.03167982999999999
# Episode 983/1000, Total Reward: -3.3097179999999997, Min Reward: -0.0346050000, Max Reward: -0.0266660000, Average Reward: -0.03309718
# Episode 984/1000, Total Reward: -3.192828, Min Reward: -0.0348360000, Max Reward: -0.0263380000, Average Reward: -0.03192828
# Episode 985/1000, Total Reward: -3.1713149999999994, Min Reward: -0.0349540000, Max Reward: -0.0264290000, Average Reward: -0.031713149999999996
# Episode 986/1000, Total Reward: -3.1582059999999994, Min Reward: -0.0347240000, Max Reward: -0.0263240000, Average Reward: -0.031582059999999995
# Episode 987/1000, Total Reward: -3.318406999999999, Min Reward: -0.0346180000, Max Reward: -0.0277860000, Average Reward: -0.033184069999999996
# Episode 988/1000, Total Reward: -3.170220999999999, Min Reward: -0.0346550000, Max Reward: -0.0264160000, Average Reward: -0.031702209999999995
# Episode 989/1000, Total Reward: -3.1733170000000004, Min Reward: -0.0345770000, Max Reward: -0.0264930000, Average Reward: -0.03173317
# Episode 990/1000, Total Reward: -3.243749999999999, Min Reward: -0.0345450000, Max Reward: -0.0265810000, Average Reward: -0.0324375
# Episode 991/1000, Total Reward: -3.2377060000000006, Min Reward: -0.0348010000, Max Reward: -0.0263690000, Average Reward: -0.032377060000000006
# Episode 992/1000, Total Reward: -3.180971000000001, Min Reward: -0.0346330000, Max Reward: -0.0264240000, Average Reward: -0.03180971
# Episode 993/1000, Total Reward: -3.1864949999999994, Min Reward: -0.0346140000, Max Reward: -0.0265300000, Average Reward: -0.031864949999999996
# Episode 994/1000, Total Reward: -3.3319360000000002, Min Reward: -0.0348460000, Max Reward: -0.0284420000, Average Reward: -0.03331936
# Episode 995/1000, Total Reward: -3.1912710000000004, Min Reward: -0.0347590000, Max Reward: -0.0264810000, Average Reward: -0.03191271
# Episode 996/1000, Total Reward: -3.1743699999999997, Min Reward: -0.0347980000, Max Reward: -0.0264900000, Average Reward: -0.0317437
# Episode 997/1000, Total Reward: -3.1676999999999995, Min Reward: -0.0347210000, Max Reward: -0.0264510000, Average Reward: -0.031677
# Episode 998/1000, Total Reward: -3.3288469999999992, Min Reward: -0.0344890000, Max Reward: -0.0295730000, Average Reward: -0.03328847
# Episode 999/1000, Total Reward: -3.1728119999999986, Min Reward: -0.0348180000, Max Reward: -0.0264460000, Average Reward: -0.031728120000000005
# Episode 1000/1000, Total Reward: -3.1555370000000003, Min Reward: -0.0345080000, Max Reward: -0.0263630000, Average Reward: -0.031555370000000006

# %%
class CompilerEnv:
    def __init__(self, code_path):
        self.code_path = code_path
        self.flags = compatible_flags
        self.state_space = len(self.flags)
        self.action_space = len(self.flags)
        self.current_state = tuple([0] * self.state_space)

    def reset(self):
        self.current_state = tuple([0] * self.state_space)
        return self.current_state

    def compile_and_measure(self, flags):
        flags_str = ' '.join([self.flags[i] for i, flag in enumerate(flags) if flag])
        compile_command = f"gcc {self.code_path} {flags_str} -o output"
        run_command = "./output"

        try:
            compile_result = subprocess.run(compile_command, shell=True, capture_output=True, text=True, timeout=10)
            if compile_result.returncode != 0:
                print("Compilation failed:", compile_result.stderr)
                return float('inf')

            subprocess.run(f"chmod +x output", shell=True)

            run_result = subprocess.run(run_command, shell=True, capture_output=True, text=True, timeout=10)
            if run_result.returncode != 0:
                print("Execution failed:", run_result.stderr)
                return float('inf')

            output_lines = run_result.stdout.strip().split('\n')
            execution_time = float(output_lines[-1])
            return execution_time

        except subprocess.TimeoutExpired:
            print("Execution timed out")
            return float('inf')

    def step(self, action):
        current_flags = list(self.current_state)
        current_flags[action] = 1 - current_flags[action]
        self.current_state = tuple(current_flags)

        execution_time = self.compile_and_measure(self.current_state)
        reward = -execution_time

        return self.current_state, reward, False

    def render(self):
        print(f"State: {self.current_state}")

# %%
import numpy as np
import subprocess
import pickle
import os
from collections import deque
import random
import matplotlib.pyplot as plt
from google.colab import files

class DQNAgent:
    def __init__(self, state_space, action_space, learning_rate=0.001, discount_factor=0.99, exploration_rate=1.0,
                 exploration_decay=0.995, memory_size=1000, batch_size=32, target_update_frequency=10):
        self.state_space = state_space
        self.action_space = action_space
        self.lr = learning_rate
        self.gamma = discount_factor
        self.epsilon = exploration_rate
        self.epsilon_decay = exploration_decay
        self.memory = deque(maxlen=memory_size)
        self.batch_size = batch_size

        # Initialize the main and target networks
        self.model = DQNetwork(state_space, action_space)
        self.target_model = DQNetwork(state_space, action_space)
        self.update_target_network()

        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()

        self.target_update_frequency = target_update_frequency
        self.steps_done = 0

    def choose_action(self, state):
        # Implement epsilon-greedy action selection
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.choice(self.action_space)
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state_tensor)
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample a batch from the replay buffer
        batch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in batch:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)

            # Compute the predicted Q-values for the current state
            q_values = self.model(state_tensor)
            q_value = q_values[0, action]

            # Compute the target Q-value
            with torch.no_grad():
                next_q_values = self.target_model(next_state_tensor)
                next_q_value = torch.max(next_q_values)

            # Set the target Q-value for the current action
            target = reward + (1 - done) * self.gamma * next_q_value

            # Compute the loss
            loss = self.loss_fn(q_value, target)

            # Perform a gradient descent step
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        # Decay epsilon
        self.epsilon *= self.epsilon_decay

        # Update the target network periodically
        if self.steps_done % self.target_update_frequency == 0:
            self.update_target_network()

        self.steps_done += 1

    def update_target_network(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def save_model(self, path):
        """Saves the model parameters to a file."""
        torch.save(self.model.state_dict(), path)

    def load_model(self, path):
        """Loads the model parameters from a file."""
        self.model.load_state_dict(torch.load(path))
        self.model.eval()  # Set the model to evaluation mode

# %%
def train_dqn(agent, env, episodes=100, save_path='dqn_model.pth'):
    rewards = []

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        episode_rewards = []

        for step in range(100):
            action = agent.choose_action(state)
            next_state, reward, done = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            episode_rewards.append(reward)

            if done:
                break

        agent.replay()
        rewards.append(total_reward)
        min_reward = min(episode_rewards)
        max_reward = max(episode_rewards)
        avg_reward = np.mean(episode_rewards)

        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}, Min Reward: {min_reward:.10f}, Max Reward: {max_reward:.10f}, Average Reward: {avg_reward}")

        # Optionally save the model at specific episodes
        # if (episode + 1) % 10 == 0:
        #     agent.save_model(f'dqn_model_episode_{episode + 1}.pth')

    # Save the final model
    agent.save_model(save_path)

    plt.figure(figsize=(10, 6))
    plt.plot(range(episodes), rewards, marker='o', linestyle='-')
    plt.xlabel('Episodes')
    plt.ylabel('Total Rewards')
    plt.title('Episodes vs. Total Rewards per Episode (DQN)')
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.10f}'))
    plt.grid(True)
    plt.show()

# Example of running a DQN experiment
new_code_path = 'sum.c'  # Specify the path to your C program
env = CompilerEnv(new_code_path)
dqn_agent = DQNAgent(env.state_space, env.action_space)

train_dqn(dqn_agent, env, episodes=100, save_path='dqn_model.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c07c82a7fdd1> in <cell line: 47>()
#      45 new_code_path = 'sum.c'  # Specify the path to your C program
#      46 env = CompilerEnv(new_code_path)
# ---> 47 dqn_agent = DQNAgent(env.state_space, env.action_space)
#      48
#      49 train_dqn(dqn_agent, env, episodes=100, save_path='dqn_model.pth')
#
# <ipython-input-17-d1fe839a0fea> in __init__(self, state_space, action_space, learning_rate, discount_factor, exploration_rate, exploration_decay, memory_size, batch_size, target_update_frequency)
#      21
#      22         # Initialize the main and target networks
# ---> 23         self.model = DQNetwork(state_space, action_space)
#      24         self.target_model = DQNetwork(state_space, action_space)
#      25         self.update_target_network()
#
# NameError: name 'DQNetwork' is not defined

# %%
# Load the trained model
dqn_agent.load_model('dqn_model.pth')

# Optionally, continue training or evaluation
# train_dqn(dqn_agent, env, episodes=100)

# Evaluate the agent
state = env.reset()
done = False
while not done:
    action = dqn_agent.choose_action(state)
    next_state, reward, done = env.step(action)
    state = next_state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-489840176e70> in <cell line: 2>()
#       1 # Load the trained model
# ----> 2 dqn_agent.load_model('dqn_model.pth')
#       3
#       4 # Optionally, continue training or evaluation
#       5 # train_dqn(dqn_agent, env, episodes=100)
#
# NameError: name 'dqn_agent' is not defined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
import subprocess

# Define compatible flags for the compiler
compatible_flags = [
    '-fauto-inc-dec', '-fbranch-count-reg', '-fcombine-stack-adjustments', '-fcompare-elim',
    '-fcprop-registers', '-fdce', '-fdefer-pop', '-fdelayed-branch', '-fdse', '-fforward-propagate',
    '-fguess-branch-probability', '-fif-conversion', '-fif-conversion2', '-finline-functions-called-once',
    '-fipa-modref', '-fipa-profile', '-fipa-pure-const', '-fipa-reference', '-fipa-reference-addressable',
    '-fmerge-constants', '-fmove-loop-invariants', '-fomit-frame-pointer', '-freorder-blocks', '-fshrink-wrap',
    '-fshrink-wrap-separate', '-fsplit-wide-types', '-fssa-backprop', '-fssa-phiopt', '-ftree-bit-ccp',
    '-ftree-ccp', '-ftree-ch', '-ftree-coalesce-vars', '-ftree-copy-prop', '-ftree-dce', '-ftree-dominator-opts',
    '-ftree-dse', '-ftree-forwprop', '-ftree-fre', '-ftree-phiprop', '-ftree-pta', '-ftree-scev-cprop', '-ftree-sink',
    '-ftree-slsr', '-ftree-sra', '-ftree-ter', '-funit-at-a-time', '-falign-functions', '-falign-jumps', '-falign-labels',
    '-falign-loops', '-fcaller-saves', '-fcode-hoisting', '-fcrossjumping', '-fcse-follow-jumps', '-fcse-skip-blocks',
    '-fdelete-null-pointer-checks', '-fdevirtualize', '-fdevirtualize-speculatively', '-fexpensive-optimizations',
    '-ffinite-loops', '-fgcse', '-fgcse-lm', '-fhoist-adjacent-loads', '-finline-functions', '-finline-small-functions',
    '-findirect-inlining', '-fipa-bit-cp', '-fipa-cp', '-fipa-icf', '-fipa-ra', '-fipa-sra', '-fipa-vrp',
    '-fisolate-erroneous-paths-dereference', '-flra-remat', '-foptimize-sibling-calls', '-foptimize-strlen',
    '-fpartial-inlining', '-fpeephole2', '-freorder-blocks-algorithm=stc', '-freorder-blocks-and-partition',
    '-freorder-functions', '-frerun-cse-after-loop', '-fschedule-insns', '-fschedule-insns2', '-fsched-interblock',
    '-fsched-spec', '-fstore-merging', '-fstrict-aliasing', '-fthread-jumps', '-ftree-builtin-call-dce',
    '-ftree-loop-vectorize', '-ftree-pre', '-ftree-slp-vectorize', '-ftree-switch-conversion', '-ftree-tail-merge',
    '-ftree-vrp', '-fvect-cost-model=very-cheap', '-fgcse-after-reload', '-fipa-cp-clone', '-floop-interchange',
    '-floop-unroll-and-jam', '-fpeel-loops', '-fpredictive-commoning', '-fsplit-loops', '-fsplit-paths',
    '-ftree-loop-distribution', '-ftree-partial-pre', '-funswitch-loops', '-fvect-cost-model=dynamic',
    '-fversion-loops-for-strides'
]

# Define the neural network used for DQN
class DQNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(DQNetwork, self).__init__()
        # A simple feedforward neural network with two hidden layers
        self.fc1 = nn.Linear(state_space, 24)
        self.fc2 = nn.Linear(24, 24)
        self.fc3 = nn.Linear(24, action_space)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# DQN agent class
class DQNAgent:
    def __init__(self, state_space, action_space, learning_rate=0.001, discount_factor=0.99, exploration_rate=1.0,
                 exploration_decay=0.995, memory_size=1000, batch_size=32, target_update_frequency=10):
        self.state_space = state_space
        self.action_space = action_space
        self.lr = learning_rate
        self.gamma = discount_factor
        self.epsilon = exploration_rate
        self.epsilon_decay = exploration_decay
        self.memory = deque(maxlen=memory_size)
        self.batch_size = batch_size

        # Initialize the main and target networks
        self.model = DQNetwork(state_space, action_space)
        self.target_model = DQNetwork(state_space, action_space)
        self.update_target_network()

        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        self.loss_fn = nn.MSELoss()

        self.target_update_frequency = target_update_frequency
        self.steps_done = 0

    def choose_action(self, state):
        # Implement epsilon-greedy action selection
        if np.random.uniform(0, 1) < self.epsilon:
            return np.random.choice(self.action_space)
        state_tensor = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state_tensor)
        return torch.argmax(q_values).item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        # Sample a batch from the replay buffer
        batch = random.sample(self.memory, self.batch_size)
        for state, action, reward, next_state, done in batch:
            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)

            # Compute the predicted Q-values for the current state
            q_values = self.model(state_tensor)
            q_value = q_values[0, action]

            # Compute the target Q-value
            with torch.no_grad():
                next_q_values = self.target_model(next_state_tensor)
                next_q_value = torch.max(next_q_values)

            # Set the target Q-value for the current action
            target = reward + (1 - done) * self.gamma * next_q_value

            # Compute the loss
            loss = self.loss_fn(q_value, target)

            # Perform a gradient descent step
            self.optimizer.zero_grad()
            loss.backward()
            self.optimizer.step()

        # Decay epsilon
        self.epsilon *= self.epsilon_decay

        # Update the target network periodically
        if self.steps_done % self.target_update_frequency == 0:
            self.update_target_network()

        self.steps_done += 1

    def update_target_network(self):
        self.target_model.load_state_dict(self.model.state_dict())

    def save_model(self, path):
        """Saves the model parameters to a file."""
        torch.save(self.model.state_dict(), path)

    def load_model(self, path):
        """Loads the model parameters from a file."""
        self.model.load_state_dict(torch.load(path))
        self.model.eval()  # Set the model to evaluation mode

# Environment class for the compiler optimization task
class CompilerEnv:
    def __init__(self, code_path):
        self.code_path = code_path
        self.flags = compatible_flags
        self.state_space = len(self.flags)
        self.action_space = len(self.flags)
        self.current_state = tuple([0] * self.state_space)

    def reset(self):
        self.current_state = tuple([0] * self.state_space)
        return self.current_state

    def compile_and_measure(self, flags):
        # Convert flag indices to actual compiler flags
        flags_str = ' '.join([self.flags[i] for i, flag in enumerate(flags) if flag])
        compile_command = f"gcc {self.code_path} {flags_str} -o output"
        run_command = "./output"

        try:
            # Compile the code with the selected flags
            compile_result = subprocess.run(compile_command, shell=True, capture_output=True, text=True, timeout=10)
            if compile_result.returncode != 0:
                print("Compilation failed:", compile_result.stderr)
                return float('inf')  # Return a high cost for failed compilation

            subprocess.run(f"chmod +x output", shell=True)

            # Run the compiled program and capture the execution time
            run_result = subprocess.run(run_command, shell=True, capture_output=True, text=True, timeout=10)
            if run_result.returncode != 0:
                print("Execution failed:", run_result.stderr)
                return float('inf')  # Return a high cost for execution failure

            # Assume the last line of output is the execution time
            output_lines = run_result.stdout.strip().split('\n')
            execution_time = float(output_lines[-1])
            return execution_time

        except subprocess.TimeoutExpired:
            print("Execution timed out")
            return float('inf')  # Return a high cost for timeouts

    def step(self, action):
        # Toggle the action flag
        current_flags = list(self.current_state)
        current_flags[action] = 1 - current_flags[action]
        self.current_state = tuple(current_flags)

        # Measure performance
        execution_time = self.compile_and_measure(self.current_state)
        reward = -execution_time  # Negative reward for minimizing execution time

        # You can define a 'done' condition here if needed (e.g., based on iterations)
        return self.current_state, reward, False

    def render(self):
        print(f"State: {self.current_state}")

def train_dqn(agent, env, episodes=1500, save_path='dqn_model.pth'):
    rewards = []

    for episode in range(episodes):
        state = env.reset()
        total_reward = 0
        episode_rewards = []
        episode_states = []

        for step in range(100):
            action = agent.choose_action(state)
            next_state, reward, done = env.step(action)
            agent.remember(state, action, reward, next_state, done)
            state = next_state
            total_reward += reward
            episode_rewards.append(reward)
            episode_states.append(state)

            if done:
                break

        agent.replay()
        rewards.append(total_reward)

        # Determine the min and max reward states for this episode
        episode_min_reward = min(episode_rewards)
        episode_max_reward = max(episode_rewards)
        episode_min_reward_state = episode_states[episode_rewards.index(episode_min_reward)]
        episode_max_reward_state = episode_states[episode_rewards.index(episode_max_reward)]

        avg_reward = np.mean(episode_rewards)
        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}, Min Reward: {episode_min_reward:.10f}, Max Reward: {episode_max_reward:.10f}, Average Reward: {avg_reward:.10f}")
        print(f"Min Reward State: {episode_min_reward_state}, Max Reward State: {episode_max_reward_state}")

    # Save the final model
    agent.save_model(save_path)

    plt.figure(figsize=(10, 6))
    plt.plot(range(episodes), rewards, marker='o', linestyle='-')
    plt.xlabel('Episodes')
    plt.ylabel('Total Rewards')
    plt.title('Episodes vs. Total Rewards per Episode (DQN)')
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: f'{y:.10f}'))
    plt.grid(True)
    plt.show()

# Example of running a DQN experiment
new_code_path = 'sum.c'  # Specify the path to your C program
env = CompilerEnv(new_code_path)
dqn_agent = DQNAgent(env.state_space, env.action_space)

train_dqn(dqn_agent, env, save_path='dqn_model.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8565b599cdcd> in <cell line: 1>()
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.optim as optim
#       4 import numpy as np
#       5 import random
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     560     raise  # If __file__ is not None the cause is unknown, so just re-raise.
#     561
# --> 562 for name in dir(_C):
#     563     if name[0] != '_' and not name.endswith('Base'):
#     564         __all__.append(name)
#
# NameError: name '_C' is not defined

# %%
train_dqn(dqn_agent, env, save_path='dqn_model.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5e123cd5e01e> in <cell line: 1>()
# ----> 1 train_dqn(dqn_agent, env, save_path='dqn_model.pth')
#
# NameError: name 'dqn_agent' is not defined

# %%
train_dqn(dqn_agent, env, save_path='dqn_model.pth')

# %%
print("hello ")

# %%
print("how are you")
